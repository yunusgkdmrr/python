# %%
! pip install pandas

import pandas as pd

# %%
pd.read_csv('top_chess_players_aug_2020.csv').head(5)
# Out:
# C:\Users\Yunus\AppData\Local\Temp\ipykernel_18676\2139487004.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv('top_chess_players_aug_2020.csv').head(5)
#    Fide id                 Name Federation Gender  Year_of_birth Title  \
# 0  1503014      Carlsen, Magnus        NOR      M         1990.0    GM
# 1  2020009     Caruana, Fabiano        USA      M         1992.0    GM
# 2  4100018      Kasparov, Garry        RUS      M         1963.0    GM
# 3  8603677          Ding, Liren        CHN      M         1992.0    GM
# 4  4168119  Nepomniachtchi, Ian        RUS      M         1990.0    GM
#
#    Standard_Rating  Rapid_rating  Blitz_rating Inactive_flag
# 0           2863.0        2881.0        2886.0           NaN
# 1           2835.0        2773.0        2711.0           NaN
# 2           2812.0        2783.0        2801.0             i
# 3           2791.0        2836.0        2788.0           NaN
# ...

# %%
pd.read_csv('ChessRating.csv').head(5)
# Out:
#    Rank            Name  Country  Classic   Rapid   Blitz  Age
# 0     1         Carlsen   Norway   2855.0  2842.0  2892.0   30
# 1     2      Ding Liren    China   2799.0  2836.0  2788.0   28
# 2     3         Caruana      USA   2786.4  2775.0  2765.0   29
# 3     4  Nepomniachtchi   Russia   2782.0  2798.0  2792.0   31
# 4     5         Aronian  Armenia   2782.0  2761.0  2767.0   39

# %%
pd.read_csv('IMDB Top 250 Movies.csv').head(5)
# Out:
#    rank                      name  year  rating               genre  \
# 0     1  The Shawshank Redemption  1994     9.3               Drama
# 1     2             The Godfather  1972     9.2         Crime,Drama
# 2     3           The Dark Knight  2008     9.0  Action,Crime,Drama
# 3     4     The Godfather Part II  1974     9.0         Crime,Drama
# 4     5              12 Angry Men  1957     9.0         Crime,Drama
#
#   certificate run_time                                            tagline  \
# 0           R   2h 22m  Fear can hold you prisoner. Hope can set you f...
# 1           R   2h 55m                         An offer you can't refuse.
# 2       PG-13   2h 32m                                    Why So Serious?
# 3           R   3h 22m       All the power on earth can't change destiny.
# 4    Approved   1h 36m  Life Is In Their Hands -- Death Is On Their Mi...
#
#       budget  box_office                                              casts  \
# ...

# %%
top5 = pd.read_csv('top_chess_players_aug_2020.csv').head(5)
# Out:
# C:\Users\Yunus\AppData\Local\Temp\ipykernel_18676\1146194878.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   top5 = pd.read_csv('top_chess_players_aug_2020.csv').head(5)

# %%
top5
# Out:
#    Fide id                 Name Federation Gender  Year_of_birth Title  \
# 0  1503014      Carlsen, Magnus        NOR      M         1990.0    GM
# 1  2020009     Caruana, Fabiano        USA      M         1992.0    GM
# 2  4100018      Kasparov, Garry        RUS      M         1963.0    GM
# 3  8603677          Ding, Liren        CHN      M         1992.0    GM
# 4  4168119  Nepomniachtchi, Ian        RUS      M         1990.0    GM
#
#    Standard_Rating  Rapid_rating  Blitz_rating Inactive_flag
# 0           2863.0        2881.0        2886.0           NaN
# 1           2835.0        2773.0        2711.0           NaN
# 2           2812.0        2783.0        2801.0             i
# 3           2791.0        2836.0        2788.0           NaN
# 4           2784.0        2778.0        2785.0           NaN

# %%
amerika = top5['Federation'] == 'USA'

# %%
top5[amerika]
# Out:
#    Fide id              Name Federation Gender  Year_of_birth Title  \
# 1  2020009  Caruana, Fabiano        USA      M         1992.0    GM
#
#    Standard_Rating  Rapid_rating  Blitz_rating Inactive_flag
# 1           2835.0        2773.0        2711.0           NaN

# %%
rusya = top5['Federation']== 'RUS'

# %%
top5[rusya]
# Out:
#    Fide id                 Name Federation Gender  Year_of_birth Title  \
# 2  4100018      Kasparov, Garry        RUS      M         1963.0    GM
# 4  4168119  Nepomniachtchi, Ian        RUS      M         1990.0    GM
#
#    Standard_Rating  Rapid_rating  Blitz_rating Inactive_flag
# 2           2812.0        2783.0        2801.0             i
# 4           2784.0        2778.0        2785.0           NaN

# %%
pd.read_csv('Pokemon.csv').head(100)
# Out:
#      #                   Name  Type 1  Type 2  Total   HP  Attack  Defense  \
# 0    1              Bulbasaur   Grass  Poison    318   45      49       49
# 1    2                Ivysaur   Grass  Poison    405   60      62       63
# 2    3               Venusaur   Grass  Poison    525   80      82       83
# 3    3  VenusaurMega Venusaur   Grass  Poison    625   80     100      123
# 4    4             Charmander    Fire     NaN    309   39      52       43
# ..  ..                    ...     ...     ...    ...  ...     ...      ...
# 95  88                 Grimer  Poison     NaN    325   80      80       50
# 96  89                    Muk  Poison     NaN    500  105     105       75
# 97  90               Shellder   Water     NaN    305   30      65      100
# 98  91               Cloyster   Water     Ice    525   50      95      180
# 99  92                 Gastly   Ghost  Poison    310   30      35       30
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
pokemon = pd.read_csv('Pokemon.csv')

# %%
ates = pokemon['Type 1'] == 'Fire'

# %%
ates
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799     True
# Name: Type 1, Length: 800, dtype: bool

# %%
pokemon[ates]
# Out:
#        #                       Name Type 1    Type 2  Total   HP  Attack  \
# 4      4                 Charmander   Fire       NaN    309   39      52
# 5      5                 Charmeleon   Fire       NaN    405   58      64
# 6      6                  Charizard   Fire    Flying    534   78      84
# 7      6  CharizardMega Charizard X   Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y   Fire    Flying    634   78     104
# 42    37                     Vulpix   Fire       NaN    299   38      41
# 43    38                  Ninetales   Fire       NaN    505   73      76
# 63    58                  Growlithe   Fire       NaN    350   55      70
# 64    59                   Arcanine   Fire       NaN    555   90     110
# 83    77                     Ponyta   Fire       NaN    410   50      85
# 84    78                   Rapidash   Fire       NaN    500   65     100
# 135  126                     Magmar   Fire       NaN    495   65      95
# ...

# %%
ates2 = pokemon['Type 2'] == 'Fire'

# %%
pokemon[ates2]
# Out:
#        #                   Name    Type 1 Type 2  Total   HP  Attack  Defense  \
# 246  228               Houndour      Dark   Fire    330   45      60       30
# 247  229               Houndoom      Dark   Fire    500   75      90       50
# 248  229  HoundoomMega Houndoom      Dark   Fire    600   75      90       90
# 424  383  GroudonPrimal Groudon    Ground   Fire    770  100     180      160
# 532  479        RotomHeat Rotom  Electric   Fire    520   50      65      107
# 553  494                Victini   Psychic   Fire    600  100     100      100
# 668  607                Litwick     Ghost   Fire    275   50      30       55
# 669  608                Lampent     Ghost   Fire    370   60      40       60
# 670  609             Chandelure     Ghost   Fire    520   60      55       90
# 697  636               Larvesta       Bug   Fire    360   55      85       55
# 698  637              Volcarona       Bug   Fire    550   85      60       65
# ...

# %%
pokemon[ates | ates2].head(50)
# Out:
#        #                       Name    Type 1    Type 2  Total   HP  Attack  \
# 4      4                 Charmander      Fire       NaN    309   39      52
# 5      5                 Charmeleon      Fire       NaN    405   58      64
# 6      6                  Charizard      Fire    Flying    534   78      84
# 7      6  CharizardMega Charizard X      Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire    Flying    634   78     104
# 42    37                     Vulpix      Fire       NaN    299   38      41
# 43    38                  Ninetales      Fire       NaN    505   73      76
# 63    58                  Growlithe      Fire       NaN    350   55      70
# 64    59                   Arcanine      Fire       NaN    555   90     110
# 83    77                     Ponyta      Fire       NaN    410   50      85
# 84    78                   Rapidash      Fire       NaN    500   65     100
# ...

# %%
dragon = pokemon['Type 2'] == 'Dragon'

# %%
pokemon[dragon & ates]
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 7      130       85    100           1      False

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
faster = pokemon['Speed'] > 100

# %%
pokemon[faster]
# Out:
#        #                   Name    Type 1  Type 2  Total  HP  Attack  Defense  \
# 19    15  BeedrillMega Beedrill       Bug  Poison    495  65     150       40
# 22    18                Pidgeot    Normal  Flying    479  83      80       75
# 23    18    PidgeotMega Pidgeot    Normal  Flying    579  83      80       80
# 31    26                 Raichu  Electric     NaN    485  60      90       55
# 56    51                Dugtrio    Ground     NaN    405  35      80       50
# ..   ...                    ...       ...     ...    ...  ..     ...      ...
# 765  695              Heliolisk  Electric  Normal    481  62      55       52
# 771  701               Hawlucha  Fighting  Flying    500  78      92       75
# 772  702                Dedenne  Electric   Fairy    431  67      58       57
# 791  715                Noivern    Flying  Dragon    535  85      70       80
# 796  719    DiancieMega Diancie      Rock   Fairy    700  50     160      110
#
# ...

# %%
pokemon[faster & dragon]
# Out:
#        #                   Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# 275  254  SceptileMega Sceptile   Grass  Dragon    630  70     110       75
# 791  715                Noivern  Flying  Dragon    535  85      70       80
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 275      145       85    145           3      False
# 791       97       80    123           6      False

# %%
pokemon['Type 1'].value_counts().unique()
# Out:
# array([112,  98,  70,  69,  57,  52,  44,  32,  31,  28,  27,  24,  17,
#          4], dtype=int64)

# %%
pokemon['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
pd.read_csv('IMDB Top 250 Movies.csv').head(20)
# Out:
#     rank                                               name  year  rating  \
# 0      1                           The Shawshank Redemption  1994     9.3
# 1      2                                      The Godfather  1972     9.2
# 2      3                                    The Dark Knight  2008     9.0
# 3      4                              The Godfather Part II  1974     9.0
# 4      5                                       12 Angry Men  1957     9.0
# 5      6                                   Schindler's List  1993     9.0
# 6      7      The Lord of the Rings: The Return of the King  2003     9.0
# 7      8                                       Pulp Fiction  1994     8.9
# 8      9  The Lord of the Rings: The Fellowship of the Ring  2001     8.8
# 9     10                     The Good, the Bad and the Ugly  1966     8.8
# 10    11                                       Forrest Gump  1994     8.8
# 11    12                                         Fight Club  1999     8.8
# ...

# %%
imdb = pd.read_csv('IMDB Top 250 Movies.csv')

# %%
highest = imdb['rating']>8.0

# %%
imdb[highest]
# Out:
#      rank                      name  year  rating                       genre  \
# 0       1  The Shawshank Redemption  1994     9.3                       Drama
# 1       2             The Godfather  1972     9.2                 Crime,Drama
# 2       3           The Dark Knight  2008     9.0          Action,Crime,Drama
# 3       4     The Godfather Part II  1974     9.0                 Crime,Drama
# 4       5              12 Angry Men  1957     9.0                 Crime,Drama
# ..    ...                       ...   ...     ...                         ...
# 241   242     It Happened One Night  1934     8.1              Comedy,Romance
# 242   243                   Persona  1966     8.1              Drama,Thriller
# 244   245            The Iron Giant  1999     8.1  Animation,Action,Adventure
# 245   246                  The Help  2011     8.1                       Drama
# 246   247               Dersu Uzala  1975     8.2   Adventure,Biography,Drama
#
# ...

# %%
king = imdb['casts'].str.contains('Christian Bale')

# %%
imdb[king]
# Out:
#      rank                   name  year  rating                       genre  \
# 2       3        The Dark Knight  2008     9.0          Action,Crime,Drama
# 40     41           The Prestige  2006     8.5        Drama,Mystery,Sci-Fi
# 68     69  The Dark Knight Rises  2012     8.4                Action,Drama
# 126   127          Batman Begins  2005     8.2          Action,Crime,Drama
# 163   164   Howl's Moving Castle  2004     8.2  Animation,Adventure,Family
# 209   210         Ford v Ferrari  2019     8.1      Action,Biography,Drama
#
#     certificate run_time                                   tagline     budget  \
# 2         PG-13   2h 32m                           Why So Serious?  185000000
# 40        PG-13   2h 10m       A Friendship That Became a Rivalry.   40000000
# 68        PG-13   2h 44m                           The Legend Ends  250000000
# 126       PG-13   2h 20m                         The Legend Begins  150000000
# ...

# %%
def aktors(artist):
    kelime  = imdb['casts'].str.contains(artist) 
    df = imdb[kelime]
    return df

# %%
save = aktors('Leonardo DiCaprio')

# %%
save.to_excel('leonardo.xlsx')
